# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([3, -5, 7, 4], index = ['a', 'b', 'c', 'd'])

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
data = {
    'Country'  :  ['Belgium', 'India', 'Brazil'],
        'Capital'  :    ['Brussels', 'New Delhi', 'Brasilia'],
        'Poulation'  :   np.array( [3,4,5])
}

# %%
 pd.DataFrame(data = data, columns = ['Country', 'Capital', 'Population'])
# Out:
#    Country    Capital Population
# 0  Belgium   Brussels        NaN
# 1    India  New Delhi        NaN
# 2   Brazil   Brasilia        NaN

# %%
data = pd.read_csv('sal.csv')         #Read CSV

# %%
data.head()                                  #viewing data
# Out:
#    39          State-gov   77516   Bachelors  13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 1  38            Private  215646     HS-grad   9             Divorced
# 2  53            Private  234721        11th   7   Married-civ-spouse
# 3  28            Private  338409   Bachelors  13   Married-civ-spouse
# 4  37            Private  284582     Masters  14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male  2174  0  40  \
# 0     Exec-managerial         Husband   White     Male     0  0  13
# 1   Handlers-cleaners   Not-in-family   White     Male     0  0  40
# 2   Handlers-cleaners         Husband   Black     Male     0  0  40
# 3      Prof-specialty            Wife   Black   Female     0  0  40
# 4     Exec-managerial            Wife   White   Female     0  0  40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
data.tail(5)
# Out:
#        39      State-gov   77516    Bachelors  13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad   9              Widowed
# 32558  22        Private  201490      HS-grad   9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174  0  40  \
# 32555        Tech-support           Wife   White   Female      0  0  38
# 32556   Machine-op-inspct        Husband   White     Male      0  0  40
# 32557        Adm-clerical      Unmarried   White   Female      0  0  40
# 32558        Adm-clerical      Own-child   White     Male      0  0  20
# 32559     Exec-managerial           Wife   White   Female  15024  0  40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K

# %%
data.index
# Out:
# RangeIndex(start=0, stop=32560, step=1)

# %%
data.columns                      #shows available columns
# Out:
# Index(['39', ' State-gov', '77516', ' Bachelors', '13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', '2174', '0', '40',
#        ' United-States', ' <=50K'],
#       dtype='object')

# %%
data.describe()                     #Quick statistic summary of data
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
data.T                    #Transpose
# Out:
#                               0                   1                    2      \
# 39                               50                  38                   53
#  State-gov         Self-emp-not-inc             Private              Private
# 77516                         83311              215646               234721
#  Bachelors                Bachelors             HS-grad                 11th
# 13                               13                   9                    7
#  Never-married   Married-civ-spouse            Divorced   Married-civ-spouse
#  Adm-clerical       Exec-managerial   Handlers-cleaners    Handlers-cleaners
#  Not-in-family              Husband       Not-in-family              Husband
#  White                        White               White                Black
#  Male                          Male                Male                 Male
# 2174                              0                   0                    0
# 0                                 0                   0                    0
# 40                               13                  40                   40
#  United-States        United-States       United-States        United-States
#  <=50K                        <=50K               <=50K                <=50K
#
#                               3                    4      \
# 39                               28                   37
#  State-gov                  Private              Private
# 77516                        338409               284582
#  Bachelors                Bachelors              Masters
# 13                               13                   14
#  Never-married   Married-civ-spouse   Married-civ-spouse
#  Adm-clerical        Prof-specialty      Exec-managerial
#  Not-in-family                 Wife                 Wife
#  White                        Black                White
#  Male                        Female               Female
# 2174                              0                    0
# 0                                 0                    0
# 40                               40                   40
#  United-States                 Cuba        United-States
#  <=50K                        <=50K                <=50K
#
#                                  5                    6                7      \
# 39                                  49                   52               31
#  State-gov                     Private     Self-emp-not-inc          Private
# 77516                           160187               209642            45781
#  Bachelors                         9th              HS-grad          Masters
# 13                                   5                    9               14
#  Never-married   Married-spouse-absent   Married-civ-spouse    Never-married
#  Adm-clerical            Other-service      Exec-managerial   Prof-specialty
#  Not-in-family           Not-in-family              Husband    Not-in-family
#  White                           Black                White            White
#  Male                           Female                 Male           Female
# 2174                                 0                    0            14084
# 0                                    0                    0                0
# 40                                  16                   45               50
#  United-States                 Jamaica        United-States    United-States
#  <=50K                           <=50K                 >50K             >50K
#
#                               8                    9      ...  \
# 39                               42                   37  ...
#  State-gov                  Private              Private  ...
# 77516                        159449               280464  ...
#  Bachelors                Bachelors         Some-college  ...
# 13                               13                   10  ...
#  Never-married   Married-civ-spouse   Married-civ-spouse  ...
#  Adm-clerical       Exec-managerial      Exec-managerial  ...
#  Not-in-family              Husband              Husband  ...
#  White                        White                Black  ...
#  Male                          Male                 Male  ...
# 2174                           5178                    0  ...
# 0                                 0                    0  ...
# 40                               40                   80  ...
#  United-States        United-States        United-States  ...
#  <=50K                         >50K                 >50K  ...
#
#                               32550                32551                32552  \
# 39                               32                   43                   32
#  State-gov                  Private              Private              Private
# 77516                         34066                84661               116138
#  Bachelors                     10th            Assoc-voc              Masters
# 13                                6                   11                   14
#  Never-married   Married-civ-spouse   Married-civ-spouse        Never-married
#  Adm-clerical     Handlers-cleaners                Sales         Tech-support
#  Not-in-family              Husband              Husband        Not-in-family
#  White           Amer-Indian-Eskimo                White   Asian-Pac-Islander
#  Male                          Male                 Male                 Male
# 2174                              0                    0                    0
# 0                                 0                    0                    0
# 40                               40                   45                   11
#  United-States        United-States        United-States               Taiwan
#  <=50K                        <=50K                <=50K                <=50K
#
#                               32553             32554                32555  \
# 39                               53                22                   27
#  State-gov                  Private           Private              Private
# 77516                        321865            310152               257302
#  Bachelors                  Masters      Some-college           Assoc-acdm
# 13                               14                10                   12
#  Never-married   Married-civ-spouse     Never-married   Married-civ-spouse
#  Adm-clerical       Exec-managerial   Protective-serv         Tech-support
#  Not-in-family              Husband     Not-in-family                 Wife
#  White                        White             White                White
#  Male                          Male              Male               Female
# 2174                              0                 0                    0
# 0                                 0                 0                    0
# 40                               40                40                   38
#  United-States        United-States     United-States        United-States
#  <=50K                         >50K             <=50K                <=50K
#
#                               32556           32557           32558  \
# 39                               40              58              22
#  State-gov                  Private         Private         Private
# 77516                        154374          151910          201490
#  Bachelors                  HS-grad         HS-grad         HS-grad
# 13                                9               9               9
#  Never-married   Married-civ-spouse         Widowed   Never-married
#  Adm-clerical     Machine-op-inspct    Adm-clerical    Adm-clerical
#  Not-in-family              Husband       Unmarried       Own-child
#  White                        White           White           White
#  Male                          Male          Female            Male
# 2174                              0               0               0
# 0                                 0               0               0
# 40                               40              40              20
#  United-States        United-States   United-States   United-States
#  <=50K                         >50K           <=50K           <=50K
#
#                               32559
# 39                               52
#  State-gov             Self-emp-inc
# 77516                        287927
#  Bachelors                  HS-grad
# 13                                9
#  Never-married   Married-civ-spouse
#  Adm-clerical       Exec-managerial
#  Not-in-family                 Wife
#  White                        White
#  Male                        Female
# 2174                          15024
# 0                                 0
# 40                               40
#  United-States        United-States
#  <=50K                         >50K
#
# [15 rows x 32560 columns]

# %%
data.sort_index(axis=1, ascending=False).head()         #sorting by an axis i.e. column
# Out:
#     77516  40  39  2174  13  0   White   United-States          State-gov  \
# 0   83311  13  50     0  13  0   White   United-States   Self-emp-not-inc
# 1  215646  40  38     0   9  0   White   United-States            Private
# 2  234721  40  53     0   7  0   Black   United-States            Private
# 3  338409  40  28     0  13  0   Black            Cuba            Private
# 4  284582  40  37     0  14  0   White   United-States            Private
#
#     Not-in-family        Never-married     Male   Bachelors  \
# 0         Husband   Married-civ-spouse     Male   Bachelors
# 1   Not-in-family             Divorced     Male     HS-grad
# 2         Husband   Married-civ-spouse     Male        11th
# 3            Wife   Married-civ-spouse   Female   Bachelors
# 4            Wife   Married-civ-spouse   Female     Masters
#
#          Adm-clerical   <=50K
# 0     Exec-managerial   <=50K
# 1   Handlers-cleaners   <=50K
# 2   Handlers-cleaners   <=50K
# 3      Prof-specialty   <=50K
# 4     Exec-managerial   <=50K

# %%
data.columns = ['Age', 'Job Category', '#' , 'Degree' , 'Worked Year' , 'Martinal Status' , 'Post' , 'Personal Status' , 'Type of job' ,'Gender', '', '', 'Year', 'Country' , 'Salary']

# %%
data.head()
# Out:
#    Age       Job Category       #      Degree  Worked Year  \
# 0   50   Self-emp-not-inc   83311   Bachelors           13
# 1   38            Private  215646     HS-grad            9
# 2   53            Private  234721        11th            7
# 3   28            Private  338409   Bachelors           13
# 4   37            Private  284582     Masters           14
#
#        Martinal Status                Post Personal Status Type of job  \
# 0   Married-civ-spouse     Exec-managerial         Husband       White
# 1             Divorced   Handlers-cleaners   Not-in-family       White
# 2   Married-civ-spouse   Handlers-cleaners         Husband       Black
# 3   Married-civ-spouse      Prof-specialty            Wife       Black
# 4   Married-civ-spouse     Exec-managerial            Wife       White
#
#     Gender        Year         Country  Salary
# 0     Male  0  0    13   United-States   <=50K
# 1     Male  0  0    40   United-States   <=50K
# 2     Male  0  0    40   United-States   <=50K
# 3   Female  0  0    40            Cuba   <=50K
# 4   Female  0  0    40   United-States   <=50K

# %%
data.loc[[1028]]
# Out:
#       Age   Job Category       #    Degree  Worked Year  \
# 1028   48   Self-emp-inc  138370   Masters           14
#
#              Martinal Status    Post Personal Status          Type of job  \
# 1028   Married-spouse-absent   Sales   Not-in-family   Asian-Pac-Islander
#
#      Gender        Year Country  Salary
# 1028   Male  0  0    50   India   <=50K
